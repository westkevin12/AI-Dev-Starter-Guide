# %% [markdown]
# # The Ultimate AI Development Environment Guide
#
# Welcome. This guide is designed to take you from a standard machine to a professional-grade AI Workstation. We assume **zero prior knowledge**. Follow these steps exactly in order.
#
# **Mission:** Safely install Ubuntu Linux and configure it with Google's Antigravity IDE, Local AI models, and Professional Cloud tools.
# **Scope:** This is an **Environment Setup Guide**. It covers the fundamentals of getting your tools ready. It is NOT a programming course.
# **IDE Choice:** We recommend **Google Antigravity** for its AI-first features, but this environment supports any IDE (VS Code, PyCharm, Vim, etc.).

# %% [markdown]
# ## Phase 1: Choose Your Path (OS Installation)
#
# Select the **Route** that matches your hardware situation.
#
# ### 🗺️ The Routes
# *   **Route A: The Dual Boot** (Recommended for Beginners)
#     *   *You have a Windows PC and want to keep Windows but run Linux for AI.*
# *   **Route B: Native Linux**
#     *   *You are wiping the entire computer to be a dedicated Linux machine.*
# *   **Route C: Headless / Cloud**
#     *   *You are installing on a remote server, VM, or Proxmox container.*
#
# ---

# %% [markdown]
# ### Route A: The Dual Boot (Windows + Linux)
# *Use this if you want to keep Windows available for gaming/other apps.*
#
# #### Step A.1: Windows Preparation
# 1.  **Gather Hardware:** 1x USB Drive (8GB+), 1x Dedicated SSD.
# 2.  **Download:** [Ubuntu LTS ISO](https://ubuntu.com/download/desktop) and [Rufus](https://rufus.ie/).
# 3.  **Create USB:** Open Rufus -> Select USB -> Select Ubuntu ISO -> Start.
# 4.  **Critical Settings:**
#     *   **Disable Fast Startup** (Control Panel > Power Options).
#     *   **Disable BitLocker**.
#
# #### Step A.2: Physical Isolation (Safety First)
# 1.  **Shut down** and unplug power.
# 2.  **Unplug your Windows Drive**. (Guarantees zero data loss).
# 3.  Plug in your Target Drive.
#
# #### Step A.3: Install Ubuntu
# 1.  Boot from USB.
# 2.  Select **"Erase disk and install Ubuntu"**.
# 3.  Finish -> Restart -> Reconnect Windows Drive.
#
# ---

# %% [markdown]
# ### Route B: Native Linux (Dedicated Machine)
# *Use this if you are building a pure Linux workstation. WARNING: This wipes the entire drive.*
#
# #### Step B.1: Create Media
# 1.  Download [Ubuntu LTS ISO](https://ubuntu.com/download/desktop).
# 2.  Flash to USB using Rufus (Windows) or BalenaEtcher (Mac/Linux).
#
# #### Step B.2: Install
# 1.  Boot from USB -> Select "Try or Install Ubuntu".
# 2.  Select **"Erase disk and install Ubuntu"**.
# 3.  Follow prompts -> Restart.
#
# ---

# %% [markdown]
# ### Route C: Headless / Cloud / Proxmox
# *Use this for VMs or Cloud Instances.*
#
# #### Step C.1: Provisioning
# 1.  Create instance with **Ubuntu 22.04/24.04 LTS**.
# 2.  **Specs:** 4 vCPUs, 16GB+ RAM, 50GB+ Storage.
#
# #### Step C.2: SSH Access
# 1.  Get IP Address.
# 2.  Connect: `ssh username@your-ip-address`.
#
# ---

# %% [markdown]
# ## Phase 2: The Setup (Software)
#
# **This applies to ALL Routes.** Now let's install the tools.
#
# ### Step 2.1: Update Everything

# %%
sudo apt update
sudo apt upgrade -y

# %% [markdown]
# ### Step 2.2: Configure Workspace

# %%
# Replace with your actual GitHub username
export GITHUB_USER="your-username"

# Create directory
mkdir -p ~/github.com/$GITHUB_USER

# Create alias
echo "alias projects='cd ~/github.com/$GITHUB_USER'" >> ~/.bashrc
source ~/.bashrc

echo "Workspace created at ~/github.com/$GITHUB_USER"

# %% [markdown]
# ### Step 2.3: Configure Git Identity

# %%
git config --global user.name "Your Name"
git config --global user.email "your.email@example.com"
git config --global init.defaultBranch main

# %% [markdown]
# ### Step 2.4: Install GitHub CLI

# %%
# 1. Install
sudo mkdir -p -m 755 /etc/apt/keyrings \
&& wget -qO- https://cli.github.com/packages/githubcli-archive-keyring.gpg | sudo tee /etc/apt/keyrings/githubcli-archive-keyring.gpg > /dev/null \
&& chmod go+r /etc/apt/keyrings/githubcli-archive-keyring.gpg \
&& echo "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/githubcli-archive-keyring.gpg] https://cli.github.com/packages stable main" | sudo tee /etc/apt/sources.list.d/github-cli.list > /dev/null \
&& sudo apt update \
&& sudo apt install gh -y

# 2. Login
gh auth login

# %% [markdown]
# ## Phase 3: The Engine (Coding Tools)
#
# ### Step 3.1: Install Core Tools

# %%
sudo apt install -y make build-essential libssl-dev zlib1g-dev \
libbz2-dev libreadline-dev libsqlite3-dev wget curl llvm \
libncursesw5-dev xz-utils tk-dev libxml2-dev libxmlsec1-dev \
libffi-dev liblzma-dev git

# %% [markdown]
# ### Step 3.2: Install Pyenv (Python)

# %%
curl https://pyenv.run | bash

echo 'export PYENV_ROOT="$HOME/.pyenv"' >> ~/.bashrc
echo '[[ -d $PYENV_ROOT/bin ]] && export PATH="$PYENV_ROOT/bin:$PATH"' >> ~/.bashrc
echo 'eval "$(pyenv init -)"' >> ~/.bashrc
source ~/.bashrc

# Install 3.11.9
export PYENV_ROOT="$HOME/.pyenv"
export PATH="$PYENV_ROOT/bin:$PATH"
eval "$(pyenv init -)"

pyenv install 3.11.9
pyenv global 3.11.9
python --version

# %% [markdown]
# ### Step 3.3: Install NVM (Node.js)

# %%
curl -o- https://raw.githubusercontent.com/nvm-sh/nvm/v0.39.7/install.sh | bash

export NVM_DIR="$HOME/.nvm"
[ -s "$NVM_DIR/nvm.sh" ] && \. "$NVM_DIR/nvm.sh"

nvm install --lts
node -v

# %% [markdown]
# ### Step 3.4: Gemini CLI

# %%
npm install -g @google/gemini-cli
gemini configure

# %% [markdown]
# ### Step 3.5: Antigravity IDE
# *Note: Skip if on Headless Server*

# %%
sudo mkdir -p /etc/apt/keyrings
curl -fsSL https://us-central1-apt.pkg.dev/doc/repo-signing-key.gpg | sudo gpg --dearmor --yes -o /etc/apt/keyrings/antigravity-repo-key.gpg

echo "deb [signed-by=/etc/apt/keyrings/antigravity-repo-key.gpg] https://us-central1-apt.pkg.dev/projects/antigravity-auto-updater-dev/ antigravity-debian main" | sudo tee /etc/apt/sources.list.d/antigravity.list > /dev/null

sudo apt update
sudo apt install antigravity

# %% [markdown]
# ### Step 3.6: Docker Engine

# %%
sudo apt-get update
sudo apt-get install -y ca-certificates curl
sudo install -m 0755 -d /etc/apt/keyrings
sudo curl -fsSL https://download.docker.com/linux/ubuntu/gpg -o /etc/apt/keyrings/docker.asc
sudo chmod a+r /etc/apt/keyrings/docker.asc

echo \
  "deb [arch=$(dpkg --print-architecture) signed-by=/etc/apt/keyrings/docker.asc] https://download.docker.com/linux/ubuntu \
  $(. /etc/os-release && echo "$VERSION_CODENAME") stable" | \
  sudo tee /etc/apt/sources.list.d/docker.list > /dev/null
sudo apt-get update

sudo apt-get install -y docker-ce docker-ce-cli containerd.io docker-buildx-plugin docker-compose-plugin

sudo usermod -aG docker $USER
newgrp docker

# %% [markdown]
# ## Phase 4: Local AI
#
# ### 4.0: NVIDIA Drivers

# %%
nvidia-smi

# %% [markdown]
# ### 4.1: Ollama

# %%
curl -fsSL https://ollama.com/install.sh | sh
ollama run llama3

# %% [markdown]
# ## Phase 5: Cloud & Verification

# %%
# Install Google Cloud SDK
sudo apt install -y apt-transport-https ca-certificates gnupg
echo "deb [signed-by=/usr/share/keyrings/cloud.google.gpg] https://packages.cloud.google.com/apt cloud-sdk main" | sudo tee -a /etc/apt/sources.list.d/google-cloud-sdk.list
curl https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo apt-key --keyring /usr/share/keyrings/cloud.google.gpg add -
sudo apt update && sudo apt install -y google-cloud-cli

gcloud auth login

# %%
# Verification
nvidia-smi
docker run hello-world
git config --list
python --version
node --version
